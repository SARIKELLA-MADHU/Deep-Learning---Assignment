# %% [markdown]
# <a href="https://colab.research.google.com/github/SARIKELLA-MADHU/Deep-Learning---Assignment/blob/main/DL_ASSIGMENT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MLP**

# %% [markdown]
# ## MLP using 10 epochs

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.datasets import cifar10

# load dataset
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# normalize
X_train = X_train / 255.0
X_test = X_test / 255.0

# flatten
X_train = X_train.reshape(-1, 32*32*3)
X_test = X_test.reshape(-1, 32*32*3)

# build MLP
model = Sequential()
model.add(Dense(256, activation='relu', input_shape=(3072,)))
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))

# compile
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# train
model.fit(X_train, y_train, epochs=10, batch_size=32)

# evaluate
loss, acc = model.evaluate(X_test, y_test)
print("Accuracy:", acc)
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 25s 15ms/step - accuracy: 0.3299 - loss: 1.8585
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 38s 13ms/step - accuracy: 0.3968 - loss: 1.6829
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - accuracy: 0.4302 - loss: 1.6004
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.4440 - loss: 1.5607
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - accuracy: 0.4580 - loss: 1.5217
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - accuracy: 0.4651 - loss: 1.4992
# Epoch 7/10
# ...

# %% [markdown]
# ## Changing batch size and epochs to check the Accuracy

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.datasets import cifar10

# load dataset
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# normalize
X_train = X_train / 255.0
X_test = X_test / 255.0

# flatten
X_train = X_train.reshape(-1, 32*32*3)
X_test = X_test.reshape(-1, 32*32*3)

# build MLP
model = Sequential()
model.add(Dense(256, activation='relu', input_shape=(3072,)))
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))

# compile
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# train
model.fit(X_train, y_train, epochs=18, batch_size=15)

# evaluate
loss, acc = model.evaluate(X_test, y_test)
print("Accuracy:", acc)
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/18
# 3334/3334 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.3277 - loss: 1.8564
# Epoch 2/18
# 3334/3334 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.3919 - loss: 1.6884
# Epoch 3/18
# 3334/3334 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.4132 - loss: 1.6329
# Epoch 4/18
# 3334/3334 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.4288 - loss: 1.5881
# Epoch 5/18
# 3334/3334 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.4400 - loss: 1.5575
# Epoch 6/18
# 3334/3334 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.4483 - loss: 1.5404
# Epoch 7/18
# ...

# %% [markdown]
# As batch size Increases the model get more updates of weights per epoch and it give more better generalised model but more epochs make the model to remember the values and can leads to overfitting

# %%
train_acc = model.evaluate(X_train, y_train)[1]
test_acc = model.evaluate(X_test, y_test)[1]

print("Train Accuracy:", train_acc)
print("Test Accuracy:", test_acc)
# Out:
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5020 - loss: 1.3866
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4665 - loss: 1.4942
# Train Accuracy: 0.502020001411438
# Test Accuracy: 0.46650001406669617

# %%
history = model.fit(X_train, y_train,
                    epochs=5,
                    batch_size=32,
                    validation_split=0.2)
# Out:
# Epoch 1/5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.5134 - loss: 1.3589 - val_accuracy: 0.5077 - val_loss: 1.3919
# Epoch 2/5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5108 - loss: 1.3574 - val_accuracy: 0.4990 - val_loss: 1.4117
# Epoch 3/5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5142 - loss: 1.3578 - val_accuracy: 0.4995 - val_loss: 1.4061
# Epoch 4/5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5160 - loss: 1.3478 - val_accuracy: 0.5094 - val_loss: 1.3961
# Epoch 5/5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5169 - loss: 1.3433 - val_accuracy: 0.5039 - val_loss: 1.4072

# %%
import matplotlib.pyplot as plt

# accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Accuracy")
plt.legend(['train', 'val'])
plt.show()

# loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Loss")
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# # **Learning Rate And Optimizers**

# %% [markdown]
# ## Training with different optimizers(SGD,SGD with momentum ,Nestrov,Adagrad,RMSProp,Adadelta,Adam) with learning rate

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD, Adam, RMSprop, Adagrad, Adadelta

# load KMNIST (from keras)
from tensorflow.keras.datasets import fashion_mnist

# NOTE: KMNIST is not in keras by default
# So we simulate using fashion_mnist OR you can download KMNIST CSV

(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# combine
X = np.concatenate((X_train, X_test))
y = np.concatenate((y_train, y_test))

# reshape
X = X.reshape(-1, 784) / 255.0

# split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# optimizers
optimizers = {
    "SGD": SGD(learning_rate=0.01),
    "SGD_Momentum": SGD(learning_rate=0.01, momentum=0.9),
    "Nesterov": SGD(learning_rate=0.01, momentum=0.9, nesterov=True),
    "Adagrad": Adagrad(learning_rate=0.01),
    "RMSProp": RMSprop(learning_rate=0.001),
    "Adadelta": Adadelta(),
    "Adam": Adam(learning_rate=0.001)
}

results = {}

for name, opt in optimizers.items():
    print("\nTraining with", name)

    model = Sequential()
    model.add(Dense(128, activation='relu', input_shape=(784,)))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(10, activation='softmax'))

    model.compile(optimizer=opt,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    history = model.fit(X_train, y_train,
                        epochs=5,
                        batch_size=32,
                        validation_split=0.2,
                        verbose=0)

    results[name] = history.history['val_accuracy'][-1]

print("\nFinal Results:", results)
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# Training with SGD
#
# Training with SGD_Momentum
#
# Training with Nesterov
#
# Training with Adagrad
#
# Training with RMSProp
#
# Training with Adadelta
#
# Training with Adam
#
# Final Results: {'SGD': 0.8583928346633911, 'SGD_Momentum': 0.8796428442001343, 'Nesterov': 0.873839259147644, 'Adagrad': 0.8627678751945496, 'RMSProp': 0.8739285469055176, 'Adadelta': 0.6324107050895691, 'Adam': 0.876964271068573}

# %% [markdown]
# ##Cheking How epochs makes changes in training and testing accuracy

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# load train data
train_data = pd.read_csv("/content/mnist_train.csv")
X_train = train_data.drop("label", axis=1) / 255.0
y_train = train_data["label"]

# load test data
test_data = pd.read_csv("/content/mnist_test.csv")
X_test = test_data.drop("label", axis=1) / 255.0
y_test = test_data["label"]

# build model
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(784,)))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

# compile
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# train
history = model.fit(X_train, y_train,
                    epochs=30,
                    batch_size=32,
                    validation_split=0.2)

# evaluate on TEST data
test_loss, test_acc = model.evaluate(X_test, y_test)

print("Test Accuracy:", test_acc)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9056 - loss: 0.3235 - val_accuracy: 0.9480 - val_loss: nan
# Epoch 2/30
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9600 - loss: 0.1341 - val_accuracy: 0.9639 - val_loss: nan
# Epoch 3/30
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9732 - loss: 0.0864 - val_accuracy: 0.9590 - val_loss: nan
# Epoch 4/30
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9801 - loss: 0.0636 - val_accuracy: 0.9604 - val_loss: nan
# Epoch 5/30
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9831 - loss: 0.0514 - val_accuracy: 0.9653 - val_loss: nan
# Epoch 6/30
# ...

# %% [markdown]
# Using the optimal number of epochs make the model to be generalized because when epochs becomes more testing accuracy becomes reduces and training accuracy becomes more which is overfitting

# %% [markdown]
# # ***Regularization***

# %% [markdown]
# L2 Reg

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.regularizers import l2

# load data
train = pd.read_csv("/content/fashion-mnist_train.csv")
test = pd.read_csv("/content/fashion-mnist_test.csv")

X_train = train.drop("label", axis=1) / 255.0
y_train = train["label"]

X_test = test.drop("label", axis=1) / 255.0
y_test = test["label"]

# model with L2
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(784,), kernel_regularizer=l2(0.001)))
model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.001)))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=10, validation_split=0.2)

model.evaluate(X_test, y_test)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8083 - loss: 0.7047 - val_accuracy: 0.8308 - val_loss: 0.6080
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8455 - loss: 0.5434 - val_accuracy: 0.8558 - val_loss: 0.5080
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8536 - loss: 0.5047 - val_accuracy: 0.8529 - val_loss: 0.4970
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8579 - loss: 0.4814 - val_accuracy: 0.8448 - val_loss: 0.5190
# Epoch 5/10
# ...

# %% [markdown]
# In L2 regularization the model don't make the weights to zero but instead it makes near to zero and it gives good generalization

# %% [markdown]
# ## Droupout

# %%
from tensorflow.keras.layers import Dropout, Flatten

# load data
train = pd.read_csv("/content/fashion-mnist_train.csv")
test = pd.read_csv("/content/fashion-mnist_test.csv")

X_train = train.drop("label", axis=1) / 255.0
y_train = train["label"]

X_test = test.drop("label", axis=1) / 255.0
y_test = test["label"]

# Reshape X_train and X_test to 4D image format for the model
X_train_reshaped = X_train.values.reshape(-1, 28, 28, 1)
X_test_reshaped = X_test.values.reshape(-1, 28, 28, 1)

# model with Dropout and Flatten layer
model = Sequential()
model.add(Flatten(input_shape=(28, 28, 1))) # Flatten layer to handle 4D input
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train_reshaped, y_train, epochs=10, validation_split=0.2)
model.evaluate(X_test_reshaped, y_test)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.6966 - loss: 0.8555 - val_accuracy: 0.8282 - val_loss: 0.4948
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7895 - loss: 0.5995 - val_accuracy: 0.8357 - val_loss: 0.4502
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8080 - loss: 0.5467 - val_accuracy: 0.8369 - val_loss: 0.4332
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8189 - loss: 0.5194 - val_accuracy: 0.8521 - val_loss: 0.4158
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8248 - loss: 0.5030 - val_accuracy: 0.8572 - val_loss: 0.3951
# Epoch 6/10
# ...

# %% [markdown]
# ## Early stopping

# %%
from tensorflow.keras.callbacks import EarlyStopping

early = EarlyStopping(monitor='val_loss', patience=2)

model.fit(X_train, y_train,
          epochs=30,
          validation_split=0.2,
          callbacks=[early])
# Out:
# Epoch 1/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8404 - loss: 0.4482 - val_accuracy: 0.8648 - val_loss: 0.3666
# Epoch 2/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8419 - loss: 0.4425 - val_accuracy: 0.8692 - val_loss: 0.3682
# Epoch 3/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8448 - loss: 0.4339 - val_accuracy: 0.8703 - val_loss: 0.3758

# %% [markdown]
# ## Data Augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.1,
    horizontal_flip=True
)

# reshape for image format
X_train_img = X_train.values.reshape(-1,28,28,1)

datagen.fit(X_train_img)

model.fit(datagen.flow(X_train_img, y_train.values, batch_size=32),
          epochs=10)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 25s 12ms/step - accuracy: 0.6248 - loss: 0.9999
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 22s 12ms/step - accuracy: 0.7275 - loss: 0.7452
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 22s 12ms/step - accuracy: 0.7467 - loss: 0.7003
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 12ms/step - accuracy: 0.7572 - loss: 0.6715
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 12ms/step - accuracy: 0.7629 - loss: 0.6552
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.7681 - loss: 0.6430
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 22s 12ms/step - accuracy: 0.7700 - loss: 0.6355
# Epoch 8/10
# ...

# %% [markdown]
# ## Adding Noise

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

noise = np.random.normal(0, 0.1, X_train.shape)
X_train_noisy = X_train + noise

# Re-define the model to accept the 2D noisy input for this section
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(784,))) # Expects 2D flattened input
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train_noisy, y_train, epochs=10, validation_split=0.2)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8084 - loss: 0.5282 - val_accuracy: 0.8460 - val_loss: 0.4303
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8562 - loss: 0.3908 - val_accuracy: 0.8571 - val_loss: 0.4066
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8755 - loss: 0.3399 - val_accuracy: 0.8523 - val_loss: 0.4036
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8858 - loss: 0.3108 - val_accuracy: 0.8659 - val_loss: 0.3765
# Epoch 5/10
# ...

# %% [markdown]
# ## Ensemble Methods

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import numpy as np

# model 1
model1 = Sequential([
    Dense(128, activation='relu', input_shape=(784,)),
    Dense(10, activation='softmax')
])

# model 2
model2 = Sequential([
    Dense(128, activation='relu', input_shape=(784,)),
    Dense(10, activation='softmax')
])


model1.compile(optimizer=Adam(0.001),
               loss='sparse_categorical_crossentropy',
               metrics=['accuracy'])

model2.compile(optimizer=Adam(0.001),
               loss='sparse_categorical_crossentropy',
               metrics=['accuracy'])

# train
model1.fit(X_train, y_train, epochs=3, batch_size=32, verbose=0)
model2.fit(X_train, y_train, epochs=3, batch_size=32, verbose=0)

# evaluate individually
acc1 = model1.evaluate(X_test, y_test, verbose=0)[1]
acc2 = model2.evaluate(X_test, y_test, verbose=0)[1]

print("Model 1 Accuracy:", acc1)
print("Model 2 Accuracy:", acc2)

# predictions
pred1 = model1.predict(X_test)
pred2 = model2.predict(X_test)

# ensemble (average)
final_pred = (pred1 + pred2) / 2

# convert to labels
final_labels = np.argmax(final_pred, axis=1)

# accuracy of ensemble
ensemble_acc = np.mean(final_labels == y_test)

print("Ensemble Accuracy:", ensemble_acc)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model 1 Accuracy: 0.880299985408783
# Model 2 Accuracy: 0.8644000291824341
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Ensemble Accuracy: 0.8782

# %% [markdown]
# # CNN

# %% [markdown]
# ### **LeNet5**
#
# In this we are going to learn how to identify the numbers in the mnist data images.
# In this we use total 7 layers excluding input layer

# %%
# Import Libraries
import keras
from keras import datasets, layers, models
from keras.models import Sequential
from keras.layers import Conv2D, AveragePooling2D, Flatten, Dense
import matplotlib.pyplot as plt

# Load CIFAR-10
(x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()

# Normalize
x_train = x_train / 255.0
x_test = x_test / 255.0

# One-hot encoding
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

# Split validation
x_train_main = x_train[:40000]
y_train_main = y_train[:40000]
x_val = x_train[40000:]
y_val = y_train[40000:]

# Build Model (LeNet adapted)
model = Sequential()

model.add(Conv2D(6, (5,5), activation='tanh', input_shape=(32,32,3)))
model.add(AveragePooling2D((2,2)))

model.add(Conv2D(16, (5,5), activation='tanh'))
model.add(AveragePooling2D((2,2)))

model.add(Flatten())

model.add(Dense(120, activation='tanh'))
model.add(Dense(84, activation='tanh'))
model.add(Dense(10, activation='softmax'))

# Compile
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train
model.fit(x_train_main, y_train_main, epochs=15, batch_size=128,
          validation_data=(x_val, y_val))

# Evaluate
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test Accuracy:", test_acc)

# %% [markdown]
# When I increased filters, accuracy improved little. Model was able to learn more features. But training time also increased.
#
# When I increased neurons, training accuracy became high. But validation accuracy did not improve much. Model started overfitting.
#
# When I changed tanh to relu, training became faster. Accuracy also improved. Model learned better than before.
#
# When I used max pooling, performance improved slightly. Model focused on important features. It worked better than average pooling.
#
# When I added one more conv layer, accuracy increased. Model learned more complex patterns. But training became slow and risk of overfitting increased.

# %% [markdown]
# ## AleNet

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
import matplotlib.pyplot as plt
import gc

# Clear session
keras.backend.clear_session()

# Load MNIST
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Expand dims
x_train = tf.expand_dims(x_train, axis=-1)
x_test = tf.expand_dims(x_test, axis=-1)

# Preprocess
def process_image(image, label):
    image = tf.image.grayscale_to_rgb(image)
    image = tf.image.resize(image, (112, 112))
    return image / 255.0, tf.one_hot(label, 10)

train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_dataset = train_dataset.map(process_image).batch(16).shuffle(1000).prefetch(tf.data.AUTOTUNE)

test_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test))
test_dataset = test_dataset.map(process_image).batch(16).prefetch(tf.data.AUTOTUNE)

# Mixed precision
tf.keras.mixed_precision.set_global_policy('mixed_float16')

# -------- Modified AlexNet --------
model = Sequential()

# Increased filters (experiment)
model.add(Conv2D(128, (11,11), strides=(4,4), activation='relu', input_shape=(112,112,3)))
model.add(MaxPooling2D((3,3), strides=(2,2)))

model.add(Conv2D(256, (5,5), padding='same', activation='relu'))
model.add(MaxPooling2D((3,3), strides=(2,2)))

model.add(Conv2D(512, (3,3), padding='same', activation='relu'))
model.add(Conv2D(512, (3,3), padding='same', activation='relu'))
model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
model.add(MaxPooling2D((3,3), strides=(2,2)))

model.add(Flatten())

# Increased neurons + dropout change
model.add(Dense(2048, activation='relu'))
model.add(Dropout(0.6))

model.add(Dense(2048, activation='relu'))
model.add(Dropout(0.6))

model.add(Dense(10, activation='softmax'))

# Compile
model.compile(
    optimizer=keras.optimizers.Adam(),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

# Train
history = model.fit(train_dataset, epochs=2, validation_data=test_dataset)

# Evaluate
test_loss, test_acc = model.evaluate(test_dataset)
print("Test accuracy:", test_acc)

gc.collect()

# Plot
plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Accuracy")
plt.legend(["train","val"])

plt.subplot(1,2,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Loss")
plt.legend(["train","val"])

plt.show()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 128)    │        46,592 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 12, 12, 256)    │       819,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 5, 5, 512)      │     1,180,160 │
# ...

# %% [markdown]
# When I increased filters and layers in AlexNet, model learned more features. Accuracy improved little but training became very slow. It shows big models are not needed for simple data.
#
# When I used dropout, overfitting reduced. Training accuracy decreased slightly but validation accuracy became stable. Model generalized better.
#
# When I used mixed precision, memory usage reduced. Training became faster on GPU. But accuracy stayed almost same.
#
# When I used small batch size, model trained properly without memory error. Training was slower but stable. Large batch was causing memory problem.

# %% [markdown]
# ## ZFNet

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# =========================
# 1. Load Dataset (MNIST)
# =========================
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Normalize
x_train = x_train / 255.0
x_test = x_test / 255.0

# Add channel dimension (28x28 → 28x28x1)
x_train = x_train[..., tf.newaxis]
x_test = x_test[..., tf.newaxis]

# Resize to 64x64 (lighter than original ZFNet 224x224)
x_train = tf.image.resize(x_train, (64, 64))
x_test = tf.image.resize(x_test, (64, 64))

# Split validation set
val_images = x_train[:10000]
val_labels = y_train[:10000]
train_images = x_train[10000:]
train_labels = y_train[10000:]

# =========================
# 2. ZFNet (Modified for MNIST)
# =========================
def ZFNet(input_shape=(64, 64, 1), num_classes=10):
    model = models.Sequential()
    model.add(layers.Input(shape=input_shape))

    # Block 1
    model.add(layers.Conv2D(64, (5, 5), strides=1, padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.Activation('relu'))
    model.add(layers.MaxPooling2D((2, 2)))

    # Block 2
    model.add(layers.Conv2D(128, (3, 3), padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.Activation('relu'))
    model.add(layers.MaxPooling2D((2, 2)))

    # Block 3
    model.add(layers.Conv2D(256, (3, 3), padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.Activation('relu'))

    # Block 4
    model.add(layers.Conv2D(256, (3, 3), padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.Activation('relu'))

    # Pooling
    model.add(layers.MaxPooling2D((2, 2)))

    # Fully Connected Layers
    model.add(layers.Flatten())

    model.add(layers.Dense(256))
    model.add(layers.BatchNormalization())
    model.add(layers.Activation('relu'))
    model.add(layers.Dropout(0.5))

    model.add(layers.Dense(128))
    model.add(layers.BatchNormalization())
    model.add(layers.Activation('relu'))
    model.add(layers.Dropout(0.5))

    # Output Layer
    model.add(layers.Dense(num_classes, activation='softmax'))

    return model


# =========================
# 3. Create Model
# =========================
model = ZFNet(input_shape=(64, 64, 1), num_classes=10)

# =========================
# 4. Compile Model
# =========================
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# =========================
# 5. Train Model
# =========================
history = model.fit(
    train_images, train_labels,
    epochs=10,
    batch_size=32,
    validation_data=(val_images, val_labels)
)

# =========================
# 6. Evaluate Model
# =========================
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"\nTest Accuracy: {test_acc:.4f}")

# =========================
# 7. Model Summary
# =========================
model.summary()
# Out:
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 52s 25ms/step - accuracy: 0.9455 - loss: 0.1927 - val_accuracy: 0.9776 - val_loss: 0.0749
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9760 - loss: 0.0850 - val_accuracy: 0.9888 - val_loss: 0.0406
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 32s 20ms/step - accuracy: 0.9809 - loss: 0.0661 - val_accuracy: 0.9883 - val_loss: 0.0383
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9839 - loss: 0.0555 - val_accuracy: 0.9891 - val_loss: 0.0391
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9864 - loss: 0.0486 - val_accuracy: 0.9913 - val_loss: 0.0299
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 31s 20ms/step - accuracy: 0.9881 - loss: 0.0404 - val_accuracy: 0.9911 - val_loss: 0.0350
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9887 - loss: 0.0378 - val_accuracy: 0.9929 - val_loss: 0.0246
# Epoch 8/10
# ...

# %% [markdown]
# ZFNet improves AlexNet by using smaller stride and better filter sizes to reduce information loss. It introduces visualization using deconvolution to understand what features the CNN learns, making model design more efficient and interpretable.

# %% [markdown]
# ## VGG

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# 🔹 Load MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# 🔹 Preprocessing
x_train = x_train / 255.0
x_test = x_test / 255.0

# Add channel dimension (grayscale → 1 channel)
x_train = x_train[..., tf.newaxis]
x_test = x_test[..., tf.newaxis]

# Resize to 32x32 (closer to VGG input style)
x_train = tf.image.resize(x_train, (32, 32))
x_test = tf.image.resize(x_test, (32, 32))

# 🔹 Build VGG-like model
model = models.Sequential()

# Block 1
model.add(layers.Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(32,32,1)))
model.add(layers.Conv2D(32, (3,3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2,2)))

# Block 2
model.add(layers.Conv2D(64, (3,3), activation='relu', padding='same'))
model.add(layers.Conv2D(64, (3,3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2,2)))

# Block 3
model.add(layers.Conv2D(128, (3,3), activation='relu', padding='same'))
model.add(layers.Conv2D(128, (3,3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2,2)))

# Fully Connected Layers
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# 🔹 Compile model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# 🔹 Train model
history = model.fit(
    x_train, y_train,
    epochs=2,
    batch_size=64,
    validation_split=0.1
)

# 🔹 Evaluate model
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test Accuracy:", test_acc)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/2
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - accuracy: 0.9518 - loss: 0.1506 - val_accuracy: 0.9895 - val_loss: 0.0381
# Epoch 2/2
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9863 - loss: 0.0434 - val_accuracy: 0.9923 - val_loss: 0.0288
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9902 - loss: 0.0290
# Test Accuracy: 0.9901999831199646

# %% [markdown]
# Convolution layers are extracting features step by step First edges Then shapes Then digit patterns Increasing filters (32 → 64 → 128) improves feature learning MaxPooling is reducing size and helping in faster computation

# %% [markdown]
# ## RESNet

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Load data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Normalize
x_train = x_train / 255.0
x_test = x_test / 255.0

# Add channel dimension
x_train = x_train[..., tf.newaxis]
x_test = x_test[..., tf.newaxis]

def residual_block(x, filters, stride=1):
    shortcut = x
    if stride != 1 or x.shape[-1] != filters:
        shortcut = layers.Conv2D(filters, (1, 1), strides=stride, padding='same')(shortcut)
        shortcut = layers.BatchNormalization()(shortcut)

    x = layers.Conv2D(filters, (3, 3), strides=stride, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = layers.Conv2D(filters, (3, 3), padding='same')(x)
    x = layers.BatchNormalization()(x)

    x = layers.add([x, shortcut])
    x = layers.ReLU()(x)
    return x

# Build model
inputs = layers.Input(shape=(28,28,1))

x = layers.Conv2D(32, (3,3), padding='same')(inputs)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)

# Residual Blocks
x = residual_block(x, 32)
x = residual_block(x, 32)

x = residual_block(x, 64, stride=2)
x = residual_block(x, 64)

# Classification head
x = layers.GlobalAveragePooling2D()(x)
outputs = layers.Dense(10, activation='softmax')(x)

model = models.Model(inputs, outputs)

# Compile
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Train
model.fit(x_train, y_train, epochs=5, batch_size=64, validation_split=0.1)

# Evaluate
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test Accuracy:", test_acc)

# %% [markdown]
# Instead of learning full mapping, model learns residual.
# ResNet learns differently it follows skip connections rule to learn

# %% [markdown]
# ## GoogleNet

# %%
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.applications.inception_v3 import preprocess_input

# 🔹 Load MNIST
(x_train_orig, y_train_orig), (x_test_orig, y_test_orig) = tf.keras.datasets.mnist.load_data()

# 🔹 Convert to TensorFlow datasets (memory efficient)
def preprocess(image, label):
    image = tf.expand_dims(image, -1)              # (28,28,1)
    image = tf.image.grayscale_to_rgb(image)       # (28,28,3)
    image = tf.image.resize(image, (224, 224))     # required for Inception
    image = preprocess_input(image)                # Inception preprocessing
    return image, label

train_ds = tf.data.Dataset.from_tensor_slices((x_train_orig, y_train_orig))
train_ds = train_ds.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
train_ds = train_ds.shuffle(1000).batch(8).prefetch(tf.data.AUTOTUNE)  # 🔥 batch reduced

test_ds = tf.data.Dataset.from_tensor_slices((x_test_orig, y_test_orig))
test_ds = test_ds.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
test_ds = test_ds.batch(8).prefetch(tf.data.AUTOTUNE)

# 🔹 Load InceptionV3 (UNCHANGED)
base = InceptionV3(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze base
for layer in base.layers:
    layer.trainable = False

# 🔹 Custom head (UNCHANGED)
x = GlobalAveragePooling2D()(base.output)
x = Dense(64, activation='relu')(x)
output = Dense(10, activation='softmax')(x)

model = Model(inputs=base.input, outputs=output)

# 🔹 Compile
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()

# 🔹 Train (reduced epochs initially)
history = model.fit(train_ds,
                    epochs=3,   # start small to avoid crash
                    validation_data=test_ds)

# 🔹 Evaluate
test_loss, test_acc = model.evaluate(test_ds)
print("Test Accuracy:", test_acc)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 111, 111,  │        864 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 111, 111,  │         96 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %% [markdown]
# \google net is google comapny architecture, GoogLeNet applies 1×1, 3×3, 5×5 convolutions and pooling in parallel, then concatenates results. This lets the network capture both fine details and broad patterns simultaneously.
